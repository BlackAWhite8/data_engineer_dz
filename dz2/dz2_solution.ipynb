# %%
from datetime import datetime, timedelta

data_dz = ["The Moscow Times - Wednesday, October 2, 2002", "The Guardian - Friday, 11.10.13", "Daily News - Thursday, 18 August 1977"]

# %%
def task_1(papers, patterns):
    result = []
    for paper in papers:
        date = paper.split(' - ')[1]
        flag = False
        
        for pattern in patterns:
            try:
                print(datetime.strptime(date, pattern))
                flag = True
                break

            except ValueError:
                continue
                
        if  not flag:
            print("none of patterns match to date")
            
    return None

# %%
patterns = ["%A, %B %d, %Y", "%A, %d.%m.%y", "%A, %d %B %Y"]
task_1(data_dz, patterns)
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00

# %%
def date_range(start_date, end_date):
    ls = []
    current_date = datetime.strptime(start_date, '%Y-%m-%d')
    end_dt = datetime.strptime(end_date, '%Y-%m-%d')
    while current_date <= end_dt:
        ls.append(current_date)
        current_date += timedelta(days = 1)
    return ls

# %%
dates = date_range('2022-01-01', '2022-01-03')
for d in dates:
    print(d)
# Out:
# 2022-01-01 00:00:00
# 2022-01-02 00:00:00
# 2022-01-03 00:00:00
